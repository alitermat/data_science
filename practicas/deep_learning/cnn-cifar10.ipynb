# %% [markdown]
# ## 1. Librerias

# %%
# Librerias Generales
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime
import random

# Optimizadores/ EarlyStopping
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay

# Data Augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## 2. Arquitectura de red neuronal

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(64, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(128, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.3))


model.add(ks.layers.Conv2D(256, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Conv2D(256, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(256, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Conv2D(512, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(512, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(512, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(512, (3, 3), activation='relu',  padding='same'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers. Flatten())

model.add(ks.layers.Dense(512, activation='relu', kernel_initializer='he_uniform'))
model.add(ks.layers.Dropout(0.3))

model.add(ks.layers.Dense(256, activation='relu', kernel_initializer='he_uniform'))

model.add(ks.layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))

model.add(ks.layers.Dense(10, activation='softmax'))

# %%
#Resumen modelo
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_20 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_21 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_22 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  conv2d_23 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_23 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_24 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_24 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  conv2d_25 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_25 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  conv2d_26 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_26 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  conv2d_27 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_27 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_28 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_28 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  conv2d_29 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_29 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  conv2d_30 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_30 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  conv2d_31 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_31 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 4, 4, 128)         0
#
#  conv2d_32 (Conv2D)          (None, 4, 4, 256)         295168
#
#  batch_normalization_32 (Ba  (None, 4, 4, 256)         1024
#  tchNormalization)
#
#  conv2d_33 (Conv2D)          (None, 4, 4, 256)         590080
#
#  batch_normalization_33 (Ba  (None, 4, 4, 256)         1024
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 2, 2, 256)         0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 2, 2, 256)         590080
#
#  batch_normalization_34 (Ba  (None, 2, 2, 256)         1024
#  tchNormalization)
#
#  conv2d_35 (Conv2D)          (None, 2, 2, 256)         590080
#
#  batch_normalization_35 (Ba  (None, 2, 2, 256)         1024
#  tchNormalization)
#
#  dropout_9 (Dropout)         (None, 2, 2, 256)         0
#
#  conv2d_36 (Conv2D)          (None, 2, 2, 512)         1180160
#
#  batch_normalization_36 (Ba  (None, 2, 2, 512)         2048
#  tchNormalization)
#
#  conv2d_37 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  batch_normalization_37 (Ba  (None, 2, 2, 512)         2048
#  tchNormalization)
#
#  conv2d_38 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  batch_normalization_38 (Ba  (None, 2, 2, 512)         2048
#  tchNormalization)
#
#  conv2d_39 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  batch_normalization_39 (Ba  (None, 2, 2, 512)         2048
#  tchNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 1, 1, 512)         0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 1, 1, 512)         0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dense_7 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 11443562 (43.65 MB)
# Trainable params: 11435626 (43.62 MB)
# Non-trainable params: 7936 (31.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizadores

# %%
lr_schedule = ExponentialDecay(initial_learning_rate=0.001, decay_steps=10000, decay_rate=0.9)
optimizer = Adam(learning_rate=lr_schedule)

model.compile(optimizer=optimizer,
    loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=50,restore_best_weights=True)
callback_val_accuracy = EarlyStopping(monitor="val_accuracy", patience=50,restore_best_weights=True)

# %% [markdown]
# ## 4. Preparamos los datos

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

#x_train, = x_train / 255.0, 
x_test = x_test / 255.0
y_train, y_test = y_train.flatten(), y_test.flatten()

y_train_label = y_train

# %%
# Obtenemos un array con todas las labels de CIFAR10

cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintamos una muestra de imagenes del dataset, para comprobar que las imagenes estan en formato correcto. Ademas, comprobamos el tamaño del train y test.

# %%
# Mostramos una muestra de las las imagenes del dataset
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Despues de comprobar el tamaño de la muestra de entrenamiento, verificamos como contamos con 50000 muestras de train y tomamos la decision de usar un 20% de las imagenes para la validación para que nuestra red convolucional tenga suficientes imagenes para entrenar y un conjunto lo suficientemente grande para validar.

# %%
# Realizar el split train/ validación
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# ## 4.1. Data Augmentation

# %%
# Creamos nuevas imagenes con los siguientes parametros 
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    channel_shift_range=50,
    horizontal_flip=True)

train_generator = train_datagen.flow(
    x_train,  # Aquí hay que usar datos NO re-escalados... de ahi que no usemos x_train_rescaled!
    y_train,
    batch_size=30)

validation_datagen = ImageDataGenerator(
    rescale=1./255)

validation_generator = validation_datagen.flow(
    x_val,
    y_val,
    batch_size=20)

# %%
# Comprobamos la creación de imagenes
sample = random.choice(range(0,4999))

example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=1
)

plt.figure(figsize=(16,16))
for i in range(0,15):
  plt.subplot(5, 3, i+1)
  for X,y in example_generator:
    image = X[0]
    plt.imshow(image)
    break

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Entrenamiento
#
# Ajustamos el tamaño del batch, ponemos los epochs alto ya que contamos con un EarlyStopping, y utilizamos el data augmentation. Además, realizaremos la medición del tiempo de entrenamiento de la red.

# %%
t = time.perf_counter()

# %%
#Entrenamos el modelo
history = model.fit(train_generator, epochs=500,
                    use_multiprocessing=False, batch_size= 128,
                    validation_data=(validation_generator),
                    callbacks=[callback_val_loss, callback_val_accuracy])
# Out:
# Epoch 1/500
# 2024-02-23 07:48:40.445502: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout_6/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1334/1334 [==============================] - 56s 33ms/step - loss: 2.0018 - accuracy: 0.2350 - val_loss: 2.1946 - val_accuracy: 0.2548
# Epoch 2/500
# 1334/1334 [==============================] - 43s 32ms/step - loss: 1.7623 - accuracy: 0.3270 - val_loss: 2.2088 - val_accuracy: 0.3044
# Epoch 3/500
# 1334/1334 [==============================] - 43s 32ms/step - loss: 1.6496 - accuracy: 0.3857 - val_loss: 2.1068 - val_accuracy: 0.3006
# Epoch 4/500
# 1334/1334 [==============================] - 43s 32ms/step - loss: 1.5658 - accuracy: 0.4300 - val_loss: 1.6232 - val_accuracy: 0.4513
# Epoch 5/500
# 1334/1334 [==============================] - 43s 32ms/step - loss: 1.4938 - accuracy: 0.4648 - val_loss: 1.3132 - val_accuracy: 0.5478
# Epoch 6/500
# 1334/1334 [==============================] - 43s 32ms/step - loss: 1.4083 - accuracy: 0.5074 - val_loss: 1.3646 - val_accuracy: 0.5429
# Epoch 7/500
# 1334/1334 [==============================] - 43s 32ms/step - loss: 1.3441 - accuracy: 0.5401 - val_loss: 1.6126 - val_accuracy: 0.5325
# Epoch 8/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 1.2837 - accuracy: 0.5652 - val_loss: 1.1300 - val_accuracy: 0.6113
# Epoch 9/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 1.2125 - accuracy: 0.5921 - val_loss: 1.1605 - val_accuracy: 0.6042
# Epoch 10/500
# 1334/1334 [==============================] - 43s 32ms/step - loss: 1.1576 - accuracy: 0.6128 - val_loss: 1.1860 - val_accuracy: 0.6094
# Epoch 11/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 1.1118 - accuracy: 0.6314 - val_loss: 1.0946 - val_accuracy: 0.6352
# Epoch 12/500
# 1334/1334 [==============================] - 43s 32ms/step - loss: 1.0605 - accuracy: 0.6543 - val_loss: 1.2395 - val_accuracy: 0.6138
# Epoch 13/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 1.0145 - accuracy: 0.6686 - val_loss: 0.9158 - val_accuracy: 0.6882
# Epoch 14/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.9792 - accuracy: 0.6823 - val_loss: 0.8245 - val_accuracy: 0.7204
# Epoch 15/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.9349 - accuracy: 0.6946 - val_loss: 0.8147 - val_accuracy: 0.7396
# Epoch 16/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.9088 - accuracy: 0.7038 - val_loss: 0.8449 - val_accuracy: 0.7253
# Epoch 17/500
# 1334/1334 [==============================] - 43s 32ms/step - loss: 0.8830 - accuracy: 0.7143 - val_loss: 0.7911 - val_accuracy: 0.7433
# Epoch 18/500
# 1334/1334 [==============================] - 43s 32ms/step - loss: 0.8590 - accuracy: 0.7208 - val_loss: 0.7935 - val_accuracy: 0.7355
# Epoch 19/500
# 1334/1334 [==============================] - 43s 32ms/step - loss: 0.8296 - accuracy: 0.7288 - val_loss: 0.8025 - val_accuracy: 0.7375
# Epoch 20/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.8011 - accuracy: 0.7383 - val_loss: 0.8046 - val_accuracy: 0.7473
# Epoch 21/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.7899 - accuracy: 0.7424 - val_loss: 0.7221 - val_accuracy: 0.7655
# Epoch 22/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.7592 - accuracy: 0.7513 - val_loss: 0.6427 - val_accuracy: 0.7900
# Epoch 23/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.7397 - accuracy: 0.7599 - val_loss: 0.5687 - val_accuracy: 0.8092
# Epoch 24/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.7255 - accuracy: 0.7640 - val_loss: 0.6208 - val_accuracy: 0.7962
# Epoch 25/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.7060 - accuracy: 0.7706 - val_loss: 0.5877 - val_accuracy: 0.8030
# Epoch 26/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.6995 - accuracy: 0.7724 - val_loss: 0.6247 - val_accuracy: 0.7998
# Epoch 27/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.6844 - accuracy: 0.7776 - val_loss: 0.6420 - val_accuracy: 0.7898
# Epoch 28/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.6752 - accuracy: 0.7807 - val_loss: 0.5401 - val_accuracy: 0.8225
# Epoch 29/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.6603 - accuracy: 0.7854 - val_loss: 0.5526 - val_accuracy: 0.8226
# Epoch 30/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.6369 - accuracy: 0.7947 - val_loss: 0.5905 - val_accuracy: 0.8105
# Epoch 31/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.6357 - accuracy: 0.7923 - val_loss: 0.5440 - val_accuracy: 0.8202
# Epoch 32/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.6223 - accuracy: 0.7958 - val_loss: 0.5593 - val_accuracy: 0.8106
# Epoch 33/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.6185 - accuracy: 0.7994 - val_loss: 0.5118 - val_accuracy: 0.8347
# Epoch 34/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.6026 - accuracy: 0.8050 - val_loss: 0.5188 - val_accuracy: 0.8317
# Epoch 35/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.5865 - accuracy: 0.8087 - val_loss: 0.4818 - val_accuracy: 0.8399
# Epoch 36/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.5833 - accuracy: 0.8106 - val_loss: 0.5081 - val_accuracy: 0.8343
# Epoch 37/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.5706 - accuracy: 0.8117 - val_loss: 0.4606 - val_accuracy: 0.8521
# Epoch 38/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.5603 - accuracy: 0.8174 - val_loss: 0.5321 - val_accuracy: 0.8285
# Epoch 39/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.5569 - accuracy: 0.8206 - val_loss: 0.5253 - val_accuracy: 0.8319
# Epoch 40/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.5480 - accuracy: 0.8220 - val_loss: 0.4769 - val_accuracy: 0.8427
# Epoch 41/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.
500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.3005 - accuracy: 0.9006 - val_loss: 0.3373 - val_accuracy: 0.8886
# Epoch 104/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.3005 - accuracy: 0.8981 - val_loss: 0.3331 - val_accuracy: 0.8920
# Epoch 105/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2931 - accuracy: 0.9018 - val_loss: 0.3366 - val_accuracy: 0.8916
# Epoch 106/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2930 - accuracy: 0.9022 - val_loss: 0.3364 - val_accuracy: 0.8901
# Epoch 107/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2998 - accuracy: 0.8998 - val_loss: 0.3418 - val_accuracy: 0.8895
# Epoch 108/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2904 - accuracy: 0.9018 - val_loss: 0.3277 - val_accuracy: 0.8958
# Epoch 109/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2893 - accuracy: 0.9021 - val_loss: 0.3098 - val_accuracy: 0.8959
# Epoch 110/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2920 - accuracy: 0.9026 - val_loss: 0.3353 - val_accuracy: 0.8931
# Epoch 111/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2932 - accuracy: 0.9023 - val_loss: 0.3151 - val_accuracy: 0.8964
# Epoch 112/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2852 - accuracy: 0.9054 - val_loss: 0.3284 - val_accuracy: 0.8939
# Epoch 113/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2818 - accuracy: 0.9057 - val_loss: 0.3553 - val_accuracy: 0.8837
# Epoch 114/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2826 - accuracy: 0.9038 - val_loss: 0.3378 - val_accuracy: 0.8888
# Epoch 115/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2815 - accuracy: 0.9053 - val_loss: 0.3347 - val_accuracy: 0.8923
# Epoch 116/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2785 - accuracy: 0.9054 - val_loss: 0.3235 - val_accuracy: 0.8956
# Epoch 117/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2752 - accuracy: 0.9065 - val_loss: 0.3219 - val_accuracy: 0.8956
# Epoch 118/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2771 - accuracy: 0.9076 - val_loss: 0.3143 - val_accuracy: 0.8952
# Epoch 119/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2665 - accuracy: 0.9101 - val_loss: 0.3095 - val_accuracy: 0.8985
# Epoch 120/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2716 - accuracy: 0.9097 - val_loss: 0.3124 - val_accuracy: 0.8994
# Epoch 121/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2732 - accuracy: 0.9076 - val_loss: 0.3621 - val_accuracy: 0.8836
# Epoch 122/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2774 - accuracy: 0.9064 - val_loss: 0.3208 - val_accuracy: 0.8920
# Epoch 123/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2688 - accuracy: 0.9099 - val_loss: 0.3376 - val_accuracy: 0.8912
# Epoch 124/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2670 - accuracy: 0.9089 - val_loss: 0.3235 - val_accuracy: 0.8950
# Epoch 125/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2623 - accuracy: 0.9117 - val_loss: 0.3502 - val_accuracy: 0.8888
# Epoch 126/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2694 - accuracy: 0.9085 - val_loss: 0.3246 - val_accuracy: 0.8934
# Epoch 127/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2585 - accuracy: 0.9122 - val_loss: 0.3179 - val_accuracy: 0.8995
# Epoch 128/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2661 - accuracy: 0.9104 - val_loss: 0.3230 - val_accuracy: 0.8955
# Epoch 129/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2632 - accuracy: 0.9115 - val_loss: 0.3149 - val_accuracy: 0.8952
# Epoch 130/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2631 - accuracy: 0.9120 - val_loss: 0.3227 - val_accuracy: 0.8963
# Epoch 131/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2591 - accuracy: 0.9115 - val_loss: 0.3269 - val_accuracy: 0.8931
# Epoch 132/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2573 - accuracy: 0.9121 - val_loss: 0.3073 - val_accuracy: 0.8983
# Epoch 133/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2560 - accuracy: 0.9137 - val_loss: 0.3210 - val_accuracy: 0.8982
# Epoch 134/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2509 - accuracy: 0.9154 - val_loss: 0.3053 - val_accuracy: 0.9021
# Epoch 135/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2523 - accuracy: 0.9157 - val_loss: 0.3230 - val_accuracy: 0.8981
# Epoch 136/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.2543 - accuracy: 0.9134 - val_loss: 0.3017 - val_accuracy: 0.9024
# Epoch 137/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2500 - accuracy: 0.9158 - val_loss: 0.3143 - val_accuracy: 0.8979
# Epoch 138/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.2508 - accuracy: 0.9163 - val_loss: 0.3249 - val_accuracy: 0.8961
# Epoch 139/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2511 - accuracy: 0.9159 - val_loss: 0.3175 - val_accuracy: 0.8965
# Epoch 140/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2486 - accuracy: 0.9155 - val_loss: 0.3118 - val_accuracy: 0.8985
# Epoch 141/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.2424 - accuracy: 0.9173 - val_loss: 0.3060 - val_accuracy: 0.9002
# Epoch 142/500
# 1334/1334 [==============================] - 43s 32ms/step - loss: 0.2458 - accuracy: 0.9172 - val_loss: 0.3107 - val_accuracy: 0.9007
# Epoch 143/500
# 1334/1334 [==============================] - 42s 32ms/step - loss: 0.2435 - accuracy: 0.9185 - val_loss: 0.3189 - val_accuracy: 0.8992
# Epoch 144/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2399 - accuracy: 0.9199 - val_loss: 0.3037 - val_accuracy: 0.9012
# Epoch 145/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2409 - accuracy: 0.9181 - val_loss: 0.2980 - val_accuracy: 0.9042
# Epoch 146/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2437 - accuracy: 0.9180 - val_loss: 0.3095 - val_accuracy: 0.8987
# Epoch 147/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2406 - accuracy: 0.9187 - val_loss: 0.2961 - val_accuracy: 0.9056
# Epoch 148/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2366 - accuracy: 0.9201 - val_loss: 0.3281 - val_accuracy: 0.8972
# Epoch 149/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2404 - accuracy: 0.9185 - val_loss: 0.3142 - val_accuracy: 0.8990
# Epoch 150/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2341 - accuracy: 0.9214 - val_loss: 0.3149 - val_accuracy: 0.9004
# Epoch 151/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2347 - accuracy: 0.9204 - val_loss: 0.3103 - val_accuracy: 0.9030
# Epoch 152/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2346 - accuracy: 0.9204 - val_loss: 0.2948 - val_accuracy: 0.9073
# Epoch 153/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2316 - accuracy: 0.9219 - val_loss: 0.3211 - val_accuracy: 0.8985
# Epoch 154/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2342 - accuracy: 0.9211 - val_loss: 0.3018 - val_accuracy: 0.9033
# Epoch 155/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2289 - accuracy: 0.9232 - val_loss: 0.2922 - val_accuracy: 0.9048
# Epoch 156/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2347 - accuracy: 0.9211 - val_loss: 0.3088 - val_accuracy: 0.9018
# Epoch 157/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2308 - accuracy: 0.9208 - val_loss: 0.3022 - val_accuracy: 0.9037
# Epoch 158/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2307 - accuracy: 0.9221 - val_loss: 0.3085 - val_accuracy: 0.9030
# Epoch 159/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2297 - accuracy: 0.9215 - val_loss: 0.3060 - val_accuracy: 0.9033
# Epoch 160/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2289 - accuracy: 0.9211 - val_loss: 0.3212 - val_accuracy: 0.8991
# Epoch 161/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2324 - accuracy: 0.9198 - val_loss: 0.3049 - val_accuracy: 0.9025
# Epoch 162/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2287 - accuracy: 0.9220 - val_loss: 0.3000 - val_accuracy: 0.9029
# Epoch 163/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2259 - accuracy: 0.9233 - val_loss: 0.3006 - val_accuracy: 0.9037
# Epoch 164/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2240 - accuracy: 0.9236 - val_loss: 0.3006 - val_accuracy: 0.9026
# Epoch 165/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2197 - accuracy: 0.9257 - val_loss: 0.3063 - val_accuracy: 0.9033
# Epoch 166/500
# 1334/1334 [==============================] - 43s 32ms/step - loss: 0.2251 - accuracy: 0.9245 - val_loss: 0.3077 - val_accuracy: 0.8987
# Epoch 167/500
# 1334/1334 [==============================] - 44s 33ms/step - loss: 0.2220 - accuracy: 0.9245 - val_loss: 0.3165 - val_accuracy: 0.9005
# Epoch 168/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2226 - accuracy: 0.9246 - val_loss: 0.3072 - val_accuracy: 0.9002
# Epoch 169/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2205 - accuracy: 0.9261 - val_loss: 0.2867 - val_accuracy: 0.9075
# Epoch 170/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2219 - accuracy: 0.9255 - val_loss: 0.2915 - val_accuracy: 0.9055
# Epoch 171/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2212 - accuracy: 0.9245 - val_loss: 0.3107 - val_accuracy: 0.9006
# Epoch 172/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2268 - accuracy: 0.9236 - val_loss: 0.3042 - val_accuracy: 0.9017
# Epoch 173/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2187 - accuracy: 0.9260 - val_loss: 0.3034 - val_accuracy: 0.9032
# Epoch 174/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2184 - accuracy: 0.9268 - val_loss: 0.2985 - val_accuracy: 0.9031
# Epoch 175/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2142 - accuracy: 0.9271 - val_loss: 0.3079 - val_accuracy: 0.9010
# Epoch 176/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2160 - accuracy: 0.9279 - val_loss: 0.3064 - val_accuracy: 0.9016
# Epoch 177/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2156 - accuracy: 0.9275 - val_loss: 0.2987 - val_accuracy: 0.9009
# Epoch 178/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2156 - accuracy: 0.9282 - val_loss: 0.3119 - val_accuracy: 0.8993
# Epoch 179/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2131 - accuracy: 0.9280 - val_loss: 0.3074 - val_accuracy: 0.9027
# Epoch 180/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2153 - accuracy: 0.9276 - val_loss: 0.2988 - val_accuracy: 0.9036
# Epoch 181/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2115 - accuracy: 0.9278 - val_loss: 0.3078 - val_accuracy: 0.9023
# Epoch 182/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2148 - accuracy: 0.9270 - val_loss: 0.3101 - val_accuracy: 0.9043
# Epoch 183/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2090 - accuracy: 0.9301 - val_loss: 0.3236 - val_accuracy: 0.8987
# Epoch 184/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2147 - accuracy: 0.9276 - val_loss: 0.3127 - val_accuracy: 0.9032
# Epoch 185/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2117 - accuracy: 0.9283 - val_loss: 0.3038 - val_accuracy: 0.9044
# Epoch 186/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2171 - accuracy: 0.9273 - val_loss: 0.3011 - val_accuracy: 0.9049
# Epoch 187/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2129 - accuracy: 0.9278 - val_loss: 0.3065 - val_accuracy: 0.9035
# Epoch 188/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2037 - accuracy: 0.9313 - val_loss: 0.2921 - val_accuracy: 0.9071
# Epoch 189/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2131 - accuracy: 0.9270 - val_loss: 0.2986 - val_accuracy: 0.9059
# Epoch 190/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2066 - accuracy: 0.9304 - val_loss: 0.3090 - val_accuracy: 0.9011
# Epoch 191/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2084 - accuracy: 0.9286 - val_loss: 0.3008 - val_accuracy: 0.9034
# Epoch 192/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2085 - accuracy: 0.9282 - val_loss: 0.3029 - val_accuracy: 0.9049
# Epoch 193/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2087 - accuracy: 0.9291 - val_loss: 0.2957 - val_accuracy: 0.9046
# Epoch 194/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2032 - accuracy: 0.9303 - val_loss: 0.3021 - val_accuracy: 0.9055
# Epoch 195/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2062 - accuracy: 0.9302 - val_loss: 0.3042 - val_accuracy: 0.9037
# Epoch 196/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2066 - accuracy: 0.9306 - val_loss: 0.3056 - val_accuracy: 0.9031
# Epoch 197/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2108 - accuracy: 0.9279 - val_loss: 0.3054 - val_accuracy: 0.9034
# Epoch 198/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2054 - accuracy: 0.9291 - val_loss: 0.3101 - val_accuracy: 0.9018
# Epoch 199/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2006 - accuracy: 0.9320 - val_loss: 0.3093 - val_accuracy: 0.9029
# Epoch 200/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2014 - accuracy: 0.9323 - val_loss: 0.3016 - val_accuracy: 0.9043
# Epoch 201/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2105 - accuracy: 0.9280 - val_loss: 0.2996 - val_accuracy: 0.9051
# Epoch 202/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2033 - accuracy: 0.9294 - val_loss: 0.3024 - val_accuracy: 0.9023
# Epoch 203/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2008 - accuracy: 0.9314 - val_loss: 0.3046 - val_accuracy: 0.9039
# Epoch 204/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2034 - accuracy: 0.9315 - val_loss: 0.2989 - val_accuracy: 0.9052
# Epoch 205/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2071 - accuracy: 0.9294 - val_loss: 0.3006 - val_accuracy: 0.9045
# Epoch 206/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2027 - accuracy: 0.9295 - val_loss: 0.3048 - val_accuracy: 0.9044
# Epoch 207/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2001 - accuracy: 0.9327 - val_loss: 0.2998 - val_accuracy: 0.9044
# Epoch 208/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2049 - accuracy: 0.9298 - val_loss: 0.3011 - val_accuracy: 0.9051
# Epoch 209/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2014 - accuracy: 0.9316 - val_loss: 0.3014 - val_accuracy: 0.9046
# Epoch 210/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.1990 - accuracy: 0.9325 - val_loss: 0.2992 - val_accuracy: 0.9046
# Epoch 211/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.1914 - accuracy: 0.9344 - val_loss: 0.3034 - val_accuracy: 0.9037
# Epoch 212/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.1991 - accuracy: 0.9322 - val_loss: 0.3061 - val_accuracy: 0.9029
# Epoch 213/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2010 - accuracy: 0.9320 - val_loss: 0.3022 - val_accuracy: 0.9052
# Epoch 214/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.1956 - accuracy: 0.9334 - val_loss: 0.2944 - val_accuracy: 0.9078
# Epoch 215/500
# 1334/1334 [==============================] - 41s 30ms/step - loss: 0.1972 - accuracy: 0.9323 - val_loss: 0.2949 - val_accuracy: 0.9069
# Epoch 216/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.1986 - accuracy: 0.9319 - val_loss: 0.3091 - val_accuracy: 0.9021
# Epoch 217/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.1948 - accuracy: 0.9343 - val_loss: 0.2948 - val_accuracy: 0.9079
# Epoch 218/500
# 1334/1334 [==============================] - 42s 31ms/step - loss: 0.2024 - accuracy: 0.9322 - val_loss: 0.2995 - val_accuracy: 0.9055
# Epoch 219/500
# 1334/1334 [==============================] - 41s 31ms/step - loss: 0.2014 - accuracy: 0.9327 - val_loss: 0.2988 - val_accuracy: 0.9053

# %%
#Medimos tiempo de entrenamiento.
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 2:32:09.326647

# %% [markdown]
# ## 6. Evaluamos los resultados

# %%
# Medimos el accuracy en test.
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 90.270

# %%
# Creamos las graficas de perdida y Acurracy del modelo 

plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %% [markdown]
# ## 7. Guardamos el modelo

# %%
model.save('cifar10_acc90.h5')
